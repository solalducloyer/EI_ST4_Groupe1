# %% [markdown]
# <a href="https://colab.research.google.com/github/solalducloyer/EI_ST4_Groupe1/blob/main/Search_Engine_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Final Notebook
#
# This notebook is your search engine.
#
# For testing your work, we will run each cell. Thus, your code we'll have to fit the structure expected.

# %% [markdown]
# ## Initialisation
#
# - Install libraries (if you use Colab and needed),
# - Import the modules,
# - Declare global variable

# %%
# !pip install nltk
# !python -m textblob.download_corpora
# !pip install beautifulsoup4
# !pip install sentence-transformers --quiet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.65.0)
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# Finished.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.4.1)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 64.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 39.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 23.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 99.9 MB/s eta 0:00:00
#   Building wheel for sentence-transformers (setup.py) ... done

# %%
import pandas as pd
import os
from bs4 import BeautifulSoup
import re
import math
import numpy as np
import pickle
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Only if you use Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATAPATH = 'drive/MyDrive/EI_web_data/Data'

# %% [markdown]
# ###Save and load data

# %%
# Save and Load your data in Pickle format

def save_data(savepath, file_name, obj):
    with open(os.path.join(savepath, file_name), 'wb') as file:
      pickle.dump(obj, file)

def load_data(savepath, file_name):
    with open(os.path.join(savepath, file_name),'rb') as file:
      return pickle.load(file)

# %% [markdown]
# ## Extraction the data

# %%
def remove_tags(text:str)->str:
  '''retire les balises html du texte'''
  soup = BeautifulSoup(text, 'html.parser')

  # Supprimer toutes les balises de script et de style
  for script in soup(['script', 'style']):
    script.extract()

  # Obtenir le texte propre sans balises
  texte_propre = soup.get_text()
  
  # Supprimer les espaces supplémentaires et les sauts de ligne
  texte_propre = re.sub(r'\s+', ' ', texte_propre)

  return texte_propre

def extract_tokens(text:str)->list:
  '''récupère (tous) les mots de chaque phrase'''
  tokens=re.findall(r'\w+', text)     
  return [token.lower() for token in tokens]

def lemmatize(tokens:list)->list:
  '''lemmatise tous les mots de la liste'''
  wnl = WordNetLemmatizer()
  return [wnl.lemmatize(token) for token in tokens]

def remove_stopwords(word_list):
  '''retire tous les stopwords de la liste'''
  return [word for word in word_list if word not in stopwords.words('english')]


def extract_data(datapath):
    df=pd.read_xml(os.path.join(datapath, 'Posts.xml'), parser="etree", encoding="utf8")
    df['CleanBody'] = df['Body'].fillna('').apply(remove_tags)
    df['Tokens'] = df['CleanBody'].apply(extract_tokens)
    df['Words']= df['Tokens'].apply(lemmatize)
    df['MeaningfullWords'] = df['Words'].apply(remove_stopwords)

    return df

# %% [markdown]
# The firt time you execute the code, uncomment to extract data then save it (it may take a few minutes). The next times you can just load the dataframe.

# %%
# df = extract_data(datapath=DATAPATH) 
# save_data(DATAPATH, 'df.pkl', df)
df=load_data(DATAPATH, 'df.pkl')

# %% [markdown]
# ## Indexation data

# %%
def index_data(df:pd.DataFrame)-> set:
  ''' renvoie un dictionnaire de la forme 
  dic={mot:{id:f_id}}'''

  dic={}
  for rang in df.index:
    Words = df.loc[rang, 'Words']
    id = df.loc[rang,'Id']
    for word in Words:
      if word in dic.keys(): #si le mot est déjà apparu dans le corpus
        if id in dic[word].keys(): #si le mot est déjà apparu dans ce document
          dic[word][id]+=1
        else:
          dic[word][id]=1 #première occurence du mot dans ce document
      else:#première occurence du mot dans le corpus
        dic[word]={id: 1}

  return dic

# %%
# inverted_index=index_data(df)
# save_data(DATAPATH, 'inverted_index.pkl', inverted_index)
inverted_index=load_data(DATAPATH, 'inverted_index.pkl')

# %% [markdown]
# ## Search Method

# %%
MODEL_ST = SentenceTransformer('all-MiniLM-L6-v2')
#embeddings = MODEL_ST.encode(df.CleanBody.values, normalize_embeddings=True)
#save_data(DATAPATH, 'embeddings.pkl', embeddings)
embeddings=load_data(DATAPATH, 'embeddings.pkl')
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
def similarity_matrix(query, df=df, embeddings=embeddings, MODEL_ST=MODEL_ST):
  encoded_query = MODEL_ST.encode([query], normalize_embeddings=True)
  matrix=cosine_similarity(encoded_query, embeddings)
  return(matrix)


def BM25(query, df=df, inverted_index=inverted_index, k1=1.5, b=0.75):
  '''retourne une copy de la dataframe avec une colonne 'ScoreBM25' contenant le score BM25 pour la requête'''
  #extraction des mots de la requête
  processed_query=lemmatize(extract_tokens(query))

  #création d'une copie de la dataframe
  df_copy=df.copy()

  #ajout d'une colonne longueur du document
  df_copy['Lenght']=df_copy['Words'].apply(lambda x : len(x))

  N=len(df_copy) #nombre de docs dans la collection
  avgdl=df_copy['Lenght'].mean() #longueur moyenne des docs

  #calcul du score de chaque document
  scores=[]
  for rang in df_copy.index:
    doc_id=df_copy.loc[rang,'Id']
    lenght=df_copy.loc[rang,'Lenght']
    s=0

    for terme in processed_query:
      if terme not in inverted_index : 
        s+=0 #le terme n'apparait ni dans le doc ni même dans le corpus --> contribution nulle au score 
      else :
        n=len(inverted_index[terme]) # nombre de documents contenants le terme
        
        IDF=math.log((N-n+0.5)/(n+0.5))
        if doc_id in inverted_index[terme]: freq=inverted_index[terme][doc_id]
        else: freq=0
        s+=IDF*freq*(k1+1)/(freq+k1*(1-b+b*lenght/avgdl))
    
    scores.append(s)

  #ajout d'une colonne 'Queryscore' à la copie de la dataframe
  df_copy['ScoreBM25']=scores

  return scores, df_copy


def scored_df(query, df=df, inverted_index=inverted_index, k1=1.5, b=0.75, m=0.7, embeddings=embeddings, MODEL_ST=MODEL_ST):
  ''' renvoie une copie de la dataframe munie des colonnes 'ScoreBM25','CosineSimilarity', 'Xmesure' et 'MMesure' 
  XMesure est le produit du score BM25 et de la mesure cosinus
  MMesure est la moyenne pondérée par m du score BM25 normalisé et de la mesure cosinus'''
  df_copy=df.copy()
  df_copy['ScoreBM25']=BM25(query, df, inverted_index, k1, b)[0]
  df_copy['CosineSimilarity'] = similarity_matrix(query, df, embeddings, MODEL_ST)[0]
  df_copy['XMesure']=df_copy['ScoreBM25']*df_copy['CosineSimilarity']
  
  A=df_copy['ScoreBM25'].max()
  df_copy['MMesure']=df_copy['ScoreBM25']*m/A + df_copy['CosineSimilarity']*(1-m)
  return df_copy


def search(query, top=10, mesure='MMesure', df=df, inverted_index=inverted_index, k1=1.5, b=0.75, m=0.7, embeddings=embeddings, MODEL_ST=MODEL_ST):
  df_copy=scored_df(query, df, inverted_index, k1, b, m, embeddings, MODEL_ST)
  return df_copy.nlargest(top, mesure)

# %%
query='draw neural network'
search(query, top=10, mesure = 'MMesure').loc[:,['Id','Title','CleanBody','ScoreBM25','CosineSimilarity','XMesure','MMesure','ViewCount','Score']]
# Out:
#            Id                                              Title  \
# 40559   63201                                               None
# 40555   63195  How to draw neural network diagrams with this ...
# 43023   66343  Drawing Neural Network diagram for academic pa...
# 64585  104365                  What Shape Does Naive Bayes make?
# 25738   40235                                               None
# 43027   66349                                               None
# 5016    10050                           Simple ANN visualisation
# 7238    12859                                               None
# 71930  114669                                               None
# 55953   87844  How can I fix my classifier only predicting tw...
#
#                                                CleanBody  ScoreBM25  \
# 40559  I asked me something similar as well as I thou...  15.574070
# 40555  I would like to draw a neural network architec...  15.503238
# 43023  Is there any tool that one can use to draw neu...  15.019099
# 64585  Decision Trees draw straight lines to partitio...  16.622309
# 25738  I wrote some latex code to draw Deep networks ...  12.969270
# 43027  As far as I know, most researchers use general...  10.830108
# 5016   TLDR: Please help me understand the graph repr...  11.025428
# 7238   In Caffe you can use caffe/draw.py to draw the...  12.154403
# 71930  The neural network is nonlinear if, and only i...  12.345783
# 55953  I have a relatively simple 16 feature neural n...  11.944656
#
#        CosineSimilarity   XMesure   MMesure  ViewCount  Score
# 40559          0.605822  9.435117  0.837603        NaN      1
# 40555          0.595052  9.225228  0.831389     3084.0      1
# 43023          0.636582  9.560882  0.823460     9263.0      4
# 64585          0.398364  6.621737  0.819509      540.0      3
# 25738          0.618202  8.017623  0.731623        NaN     86
# 43027          0.692501  7.499859  0.663829        NaN      0
# 5016           0.627747  6.921176  0.652628      353.0      3
# 7238           0.458155  5.568605  0.649294        NaN     21
# 71930          0.377695  4.662938  0.633215        NaN      1
# 55953          0.408411  4.878327  0.625538       77.0      0

# %% [markdown]
# ## Ranking

# %%
def viewcount_ranking(query, top, mesure='MMesure'):

  results = search(query, top, mesure)

  views_tot = sum(x for x in results['ViewCount'].tolist() if not math.isnan(x))
  views_max = max(results['ViewCount'].tolist())
  posts_ids = results['Id'].tolist()

  new_scores = []

  for post_id in posts_ids:

    post_metadata = results.loc[results['Id'] == post_id]
    post_viewcount = post_metadata['ViewCount'].tolist()[0]
    post_score = post_metadata[mesure].tolist()[0]

    if not math.isnan(post_viewcount) :
      new_scores.append(post_score*math.pow(post_viewcount, 0.3))
    else :
      new_scores.append(post_score)

  results['MetadataScore'] = new_scores

  new_ranking = results.nlargest(top, 'MetadataScore')

  return new_ranking

# %%
query='draw neural network'
viewcount_ranking(query, top=10).loc[:,['Id','Title','CleanBody','ScoreBM25','CosineSimilarity','XMesure','MMesure','ViewCount','Score']]
# Out:
#            Id                                              Title  \
# 43023   66343  Drawing Neural Network diagram for academic pa...
# 40555   63195  How to draw neural network diagrams with this ...
# 64585  104365                  What Shape Does Naive Bayes make?
# 5016    10050                           Simple ANN visualisation
# 55953   87844  How can I fix my classifier only predicting tw...
# 40559   63201                                               None
# 25738   40235                                               None
# 43027   66349                                               None
# 7238    12859                                               None
# 71930  114669                                               None
#
#                                                CleanBody  ScoreBM25  \
# 43023  Is there any tool that one can use to draw neu...  15.019099
# 40555  I would like to draw a neural network architec...  15.503238
# 64585  Decision Trees draw straight lines to partitio...  16.622309
# 5016   TLDR: Please help me understand the graph repr...  11.025428
# 55953  I have a relatively simple 16 feature neural n...  11.944656
# 40559  I asked me something similar as well as I thou...  15.574070
# 25738  I wrote some latex code to draw Deep networks ...  12.969270
# 43027  As far as I know, most researchers use general...  10.830108
# 7238   In Caffe you can use caffe/draw.py to draw the...  12.154403
# 71930  The neural network is nonlinear if, and only i...  12.345783
#
#        CosineSimilarity   XMesure   MMesure  ViewCount  Score
# 43023          0.636582  9.560882  0.823460     9263.0      4
# 40555          0.595052  9.225228  0.831389     3084.0      1
# 64585          0.398364  6.621737  0.819509      540.0      3
# 5016           0.627747  6.921176  0.652628      353.0      3
# 55953          0.408411  4.878327  0.625538       77.0      0
# 40559          0.605822  9.435117  0.837603        NaN      1
# 25738          0.618202  8.017623  0.731623        NaN     86
# 43027          0.692501  7.499859  0.663829        NaN      0
# 7238           0.458155  5.568605  0.649294        NaN     21
# 71930          0.377695  4.662938  0.633215        NaN      1

# %% [markdown]
# ## Visualising Results

# %%
def visualize_output():
    # TODO
    
    return

# %% [markdown]
# ## Querying

# %%
def make_query(natural_query):
    # TODO

    return

# %% [markdown]
# ## Scoring

# %%
# Pas sûr de garder cette partie

# %% [markdown]
# ## Testing

# %%
query='mesure performance for multiclassification model'
liste_id=[6107,15989,13490,12321,22,14899,5706,15135,12851,694,9302,9443]
results=search(query, top=len(df), mesure = 'MMesure').loc[df['Id'].isin(liste_id)]
results
# Out:
#          Id  PostTypeId             CreationDate  Score  ViewCount  \
# 9533  15989           1  2016-12-29T17:39:07.967    276   340524.0
# 7741  13490           1  2016-08-17T09:35:45.110    251   391409.0
# 4383   9302           1  2015-12-10T06:22:48.927    149   164514.0
# 612     694           1  2014-07-07T19:17:04.973    150   125487.0
# 4508   9443           1  2015-12-19T19:30:35.527    171   116988.0
# 7230  12851           1  2016-07-18T17:08:17.237    164   204629.0
# 8928  15135           1  2016-11-15T14:55:04.130    184   347425.0
# 6804  12321           1  2016-06-21T10:05:08.587    238   336451.0
# 12       22           1  2014-05-14T05:58:21.927    198   286053.0
# 8752  14899           1  2016-11-03T03:10:24.893    189   316075.0
# 2307   5706           1  2015-05-07T04:11:56.600    184   135525.0
# 2642   6107           1  2015-06-13T09:56:45.397    281   264623.0
#
#                                                    Body  OwnerUserId  \
# 9533  <p>I am trying out a multiclass classification...      13518.0
# 7741  <p>I know that there is a possibility in Keras...      21560.0
# 4383  <p>In the <a href="https://www.tensorflow.org/...       8820.0
# 612   <p>I'm using Neural Networks to solve differen...        989.0
# 4508  <p>I have been building models with categorica...      10462.0
# 7230  <p>When writing a paper / making a presentatio...       8820.0
# 8928  <p>How could I randomly split a data matrix an...      21560.0
# 6804  <p>I do not understand the difference between ...      15064.0
# 12    <p>My data set contains a number of numeric at...         97.0
# 8752  <p>I have built my model. Now I want to draw t...      20618.0
# 2307  <p>Referring to the Stanford course notes on <...        793.0
# 2642  <p>I recently read <a href="http://arxiv.org/a...       8820.0
#
#              LastActivityDate  \
# 9533  2022-04-02T09:28:24.697
# 7741  2021-07-15T16:24:48.873
# 4383  2021-09-11T16:22:44.930
# 612   2018-12-11T23:39:52.667
# 4508  2022-02-20T22:17:56.370
# 7230  2022-08-29T01:27:44.843
# 8928  2022-12-05T16:13:04.480
# 6804  2021-07-08T08:09:09.163
# 12    2022-10-14T09:40:25.270
# 8752  2020-05-12T19:03:48.143
# 2307  2018-09-22T10:46:25.477
# 2642  2022-06-17T23:17:17.073
#
#                                                   Title  \
# 9533  Micro Average vs Macro average Performance in ...
# 7741  How to set class weights for imbalanced classe...
# 4383  The cross-entropy error function in neural net...
# 612             Best python library for neural networks
# 4508  When to use One Hot Encoding vs LabelEncoder v...
# 7230  How do you visualize neural network architectu...
# 8928     Train/Test/Validation Set Splitting in Sklearn
# 6804  What's the difference between fit and fit_tran...
# 12    K-Means clustering for mixed numeric and categ...
# 8752  How to draw Deep learning network architecture...
# 2307  What is the "dying ReLU" problem in neural net...
# 2642                   What are deconvolutional layers?
#
#                                                    Tags  ...  \
# 9533            <multiclass-classification><evaluation>  ...
# 7741  <deep-learning><classification><keras><weighte...  ...
# 4383                     <machine-learning><tensorflow>  ...
# 612          <machine-learning><python><neural-network>  ...
# 4508  <scikit-learn><categorical-data><feature-engin...  ...
# 7230  <machine-learning><neural-network><deep-learni...  ...
# 8928  <machine-learning><scikit-learn><cross-validat...  ...
# 6804                             <python><scikit-learn>  ...
# 12    <data-mining><clustering><octave><k-means><cat...  ...
# 8752  <machine-learning><neural-network><deep-learni...  ...
# 2307  <machine-learning><neural-network><deep-learning>  ...
# 2642  <neural-network><convolutional-neural-network>...  ...
#
#       LastEditorDisplayName  FavoriteCount  \
# 9533                   None            NaN
# 7741                   None            NaN
# 4383                   None            NaN
# 612                    None            NaN
# 4508                   None            NaN
# 7230                   None            NaN
# 8928                   None            NaN
# 6804                   None            NaN
# 12                     None            NaN
# 8752                   None            NaN
# 2307                   None            NaN
# 2642                   None            NaN
#
#                                               CleanBody  \
# 9533  I am trying out a multiclass classification se...
# 7741  I know that there is a possibility in Keras wi...
# 4383  In the MNIST For ML Beginners they define cros...
# 612   I'm using Neural Networks to solve different M...
# 4508  I have been building models with categorical d...
# 7230  When writing a paper / making a presentation a...
# 8928  How could I randomly split a data matrix and t...
# 6804  I do not understand the difference between the...
# 12    My data set contains a number of numeric attri...
# 8752  I have built my model. Now I want to draw the ...
# 2307  Referring to the Stanford course notes on Conv...
# 2642  I recently read Fully Convolutional Networks f...
#
#                                                  Tokens  \
# 9533  [i, am, trying, out, a, multiclass, classifica...
# 7741  [i, know, that, there, is, a, possibility, in,...
# 4383  [in, the, mnist, for, ml, beginners, they, def...
# 612   [i, m, using, neural, networks, to, solve, dif...
# 4508  [i, have, been, building, models, with, catego...
# 7230  [when, writing, a, paper, making, a, presentat...
# 8928  [how, could, i, randomly, split, a, data, matr...
# 6804  [i, do, not, understand, the, difference, betw...
# 12    [my, data, set, contains, a, number, of, numer...
# 8752  [i, have, built, my, model, now, i, want, to, ...
# 2307  [referring, to, the, stanford, course, notes, ...
# 2642  [i, recently, read, fully, convolutional, netw...
#
#                                                   Words  \
# 9533  [i, am, trying, out, a, multiclass, classifica...
# 7741  [i, know, that, there, is, a, possibility, in,...
# 4383  [in, the, mnist, for, ml, beginner, they, defi...
# 612   [i, m, using, neural, network, to, solve, diff...
# 4508  [i, have, been, building, model, with, categor...
# 7230  [when, writing, a, paper, making, a, presentat...
# 8928  [how, could, i, randomly, split, a, data, matr...
# 6804  [i, do, not, understand, the, difference, betw...
# 12    [my, data, set, contains, a, number, of, numer...
# 8752  [i, have, built, my, model, now, i, want, to, ...
# 2307  [referring, to, the, stanford, course, note, o...
# 2642  [i, recently, read, fully, convolutional, netw...
#
#                                        MeaningfullWords ScoreBM25  \
# 9533  [trying, multiclass, classification, setting, ...  4.928014
# 7741  [know, possibility, kera, class_weights, param...  0.000000
# 4383  [mnist, ml, beginner, define, cross, entropy, ... -0.778684
# 612   [using, neural, network, solve, different, mac...  0.000000
# 4508  [building, model, categorical, data, situation...  0.080767
# 7230  [writing, paper, making, presentation, topic, ...  0.000000
# 8928  [could, randomly, split, data, matrix, corresp...  0.000000
# 6804  [understand, difference, fit, fit_transform, m... -0.162190
# 12    [data, set, contains, number, numeric, attribu... -0.884025
# 8752  [built, model, want, draw, network, architectu... -0.193108
# 2307  [referring, stanford, course, note, convolutio... -1.088225
# 2642  [recently, read, fully, convolutional, network... -1.046584
#
#       CosineSimilarity   XMesure   MMesure
# 9533          0.442770  2.181977  0.383084
# 7741          0.248855  0.000000  0.074656
# 4383          0.268063 -0.208736  0.040876
# 612           0.117553  0.000000  0.035266
# 4508          0.100002  0.008077  0.034102
# 7230          0.109746  0.000000  0.032924
# 8928          0.101600  0.000000  0.030480
# 6804          0.108724 -0.017634  0.024381
# 12            0.206735 -0.182759  0.017128
# 8752          0.069474 -0.013416  0.011036
# 2307          0.174230 -0.189601 -0.002993
# 2642          0.100540 -0.105224 -0.022985
#
# [12 rows x 30 columns]
