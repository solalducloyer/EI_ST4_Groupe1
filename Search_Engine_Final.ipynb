# %% [markdown]
# <a href="https://colab.research.google.com/github/solalducloyer/EI_ST4_Groupe1/blob/main/Search_Engine_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Final Notebook
#
# This notebook is your search engine.
#
# For testing your work, we will run each cell. Thus, your code we'll have to fit the structure expected.

# %% [markdown]
# ## Initialisation
#
# - Install libraries (if you use Colab and needed),
# - Import the modules,
# - Declare global variable

# %%
# !pip install nltk
# !python -m textblob.download_corpora
# !pip install beautifulsoup4
# !pip install -U sentence-transformers --quiet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.65.0)
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# Finished.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.4.1)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 64.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 39.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 23.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 99.9 MB/s eta 0:00:00
#   Building wheel for sentence-transformers (setup.py) ... done

# %%
import pandas as pd
import os
from bs4 import BeautifulSoup
import re
import math
import numpy as np
import pickle
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /Users/solal/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/solal/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Only if you use Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATAPATH = 'drive/MyDrive/EI_web_data/Data'

# %% [markdown]
# ###Save and load data

# %%
# Save and Load your data in Pickle format

def save_data(savepath, file_name, obj):
    with open(os.path.join(savepath, file_name), 'wb') as file:
      pickle.dump(obj, file)

def load_data(savepath, file_name):
    with open(os.path.join(savepath, file_name),'rb') as file:
      return pickle.load(file)

# %% [markdown]
# ## Extraction the data

# %%
def remove_tags(text:str)->str:
  '''retire les balises html du texte'''
  soup = BeautifulSoup(text, 'html.parser')

  # Supprimer toutes les balises de script et de style
  for script in soup(['script', 'style']):
    script.extract()

  # Obtenir le texte propre sans balises
  texte_propre = soup.get_text()
  
  # Supprimer les espaces supplémentaires et les sauts de ligne
  texte_propre = re.sub(r'\s+', ' ', texte_propre)

  return texte_propre

def extract_tokens(text:str)->list:
  '''récupère (tous) les mots de chaque phrase'''
  tokens=re.findall(r'\w+', text)     
  return [token.lower() for token in tokens]

def lemmatize(tokens:list)->list:
  '''lemmatise tous les mots de la liste'''
  wnl = WordNetLemmatizer()
  return [wnl.lemmatize(token) for token in tokens]

def remove_stopwords(word_list):
  '''retire tous les stopwords de la liste'''
  return [word for word in word_list if word not in stopwords.words('english')]


def extract_data(datapath):
    df=pd.read_xml(os.path.join(datapath, 'Posts.xml'), parser="etree", encoding="utf8")
    df['CleanBody'] = df['Body'].fillna('').apply(remove_tags)
    df['Tokens'] = df['CleanBody'].apply(extract_tokens)
    df['Words']= df['Tokens'].apply(lemmatize)
    df['MeaningfullWords'] = df['Words'].apply(remove_stopwords)

    return df

# %% [markdown]
# The firt time you execute the code, uncomment to extract data then save it (it may take a few minutes). The next times you can just load the dataframe.

# %%
# df = extract_data(datapath=DATAPATH) 
# save_data(DATAPATH, 'df.pkl', df)
df=load_data(DATAPATH, 'df.pkl')

# %% [markdown]
# ## Indexation data

# %%
def index_data(df:pd.DataFrame)-> set:
  ''' renvoie un dictionnaire de la forme 
  dic={mot:{id:f_id}}'''

  dic={}
  for rang in df.index:
    Words = df.loc[rang, 'Words']
    id = df.loc[rang,'Id']
    for word in Words:
      if word in dic.keys(): #si le mot est déjà apparu dans le corpus
        if id in dic[word].keys(): #si le mot est déjà apparu dans ce document
          dic[word][id]+=1
        else:
          dic[word][id]=1 #première occurence du mot dans ce document
      else:#première occurence du mot dans le corpus
        dic[word]={id: 1}

  return dic

# %%
# inverted_index=index_data(df)
# save_data(DATAPATH, 'inverted_index.pkl', inverted_index)
inverted_index=load_data(DATAPATH, 'inverted_index.pkl')

# %% [markdown]
# ## Search Method

# %%
MODEL_ST = SentenceTransformer('all-MiniLM-L6-v2')
# embeddings = MODEL_ST.encode(df.CleanBody.values, normalize_embeddings=True)
# save_data(DATAPATH, 'embeddings.pkl', embeddings)
embeddings=load_data(DATAPATH, 'embeddings.pkl')
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
def similarity_matrix(query, df=df, embeddings=embeddings, MODEL_ST=MODEL_ST):
  encoded_query = MODEL_ST.encode([query], normalize_embeddings=True)
  matrix=cosine_similarity(encoded_query, embeddings)
  return(matrix)


def BM25(query, df=df, inverted_index=inverted_index, k1=1.5, b=0.75):
  '''retourne une copy de la dataframe avec une colonne 'ScoreBM25' contenant le score BM25 pour la requête'''
  #extraction des mots de la requête
  processed_query=lemmatize(extract_tokens(query))

  #création d'une copie de la dataframe
  df_copy=df.copy()

  #ajout d'une colonne longueur du document
  df_copy['Lenght']=df_copy['Words'].apply(lambda x : len(x))

  N=len(df_copy) #nombre de docs dans la collection
  avgdl=df_copy['Lenght'].mean() #longueur moyenne des docs

  #calcul du score de chaque document
  scores=[]
  for rang in df_copy.index:
    doc_id=df_copy.loc[rang,'Id']
    lenght=df_copy.loc[rang,'Lenght']
    s=0

    for terme in processed_query:
      if terme not in inverted_index : 
        s+=0 #le terme n'apparait ni dans le doc ni même dans le corpus --> contribution nulle au score 
      else :
        n=len(inverted_index[terme]) # nombre de documents contenants le terme
        
        IDF=math.log((N-n+0.5)/(n+0.5))
        if doc_id in inverted_index[terme]: freq=inverted_index[terme][doc_id]
        else: freq=0
        s+=IDF*freq*(k1+1)/(freq+k1*(1-b+b*lenght/avgdl))
    
    scores.append(s)

  #ajout d'une colonne 'Queryscore' à la copie de la dataframe
  df_copy['ScoreBM25']=scores

  return scores, df_copy


def scored_df(query, df=df, inverted_index=inverted_index, k1=1.5, b=0.75, m=0.7, embeddings=embeddings, MODEL_ST=MODEL_ST):
  ''' renvoie une copie de la dataframe munie des colonnes 'ScoreBM25','CosineSimilarity', 'Xmesure' et 'MMesure' 
  XMesure est le produit du score BM25 et de la mesure cosinus
  MMesure est la moyenne pondérée par m du score BM25 normalisé et de la mesure cosinus'''
  df_copy=df.copy()
  df_copy['ScoreBM25']=BM25(query, df, inverted_index, k1, b)[0]
  df_copy['CosineSimilarity'] = similarity_matrix(query, df, embeddings, MODEL_ST)[0]
  df_copy['XMesure']=df_copy['ScoreBM25']*df_copy['CosineSimilarity']
  
  A=df_copy['ScoreBM25'].max()
  df_copy['MMesure']=df_copy['ScoreBM25']*m/A + df_copy['CosineSimilarity']*(1-m)
  return df_copy


def search(query, top, df=df, inverted_index=inverted_index, k1=1.5, b=0.75, m=0.7, embeddings=embeddings, MODEL_ST=MODEL_ST):
  df_copy=scored_df(query, df, inverted_index, k1, b, m, embeddings, MODEL_ST)
  return df_copy.nlargest(top, 'MMesure')

# %%
query='what is stochastic gradient descent ?'
search(query, top=10)
# Out:
#           Id  PostTypeId             CreationDate  Score  ViewCount  \
# 34094  53047           1  2019-06-01T14:17:40.917      4      265.0
# 22952  36450           1  2018-08-04T06:36:04.657     75   137355.0
# 45984  70271           2  2020-03-26T14:43:26.663      0        NaN
# 37535  57795           2  2019-08-19T10:48:21.213      1        NaN
# 52361  81452           1  2020-09-09T14:21:57.233      0      125.0
# 17863  28492           2  2018-03-01T22:05:38.967      2        NaN
# 34727  53884           2  2019-06-16T04:30:06.180      5        NaN
# 56184  88153           5  2021-01-18T18:23:31.690      0        NaN
# 42036  65174           2  2019-12-20T05:36:21.150      1        NaN
# 51536  80232           1  2020-08-13T14:00:00.913      4     1259.0
#
#                                                     Body  OwnerUserId  \
# 34094  <p>As I know, Gradient Descent has three varia...      56922.0
# 22952  <p>What is the difference between Gradient Des...      57082.0
# 45984  <p>Both algorithms are quite similar. The only...      92425.0
# 37535  <p>You can see in the following link examples ...      79770.0
# 52361  <p>I am a student and I am studying machine le...      84229.0
# 17863  <p>It depends a bit on your definition, usuall...      14904.0
# 34727  <p>Gradient Descent is an optimization method ...      68023.0
# 56184  <p>Stochastic Gradient Descent (SGD) is an ite...      29169.0
# 42036  <p>First, using the appropriate terminology yo...      84626.0
# 51536  <p>Which of the following is true, given the o...      85353.0
#
#               LastActivityDate  \
# 34094  2020-12-14T16:54:45.387
# 22952  2021-02-07T20:51:58.520
# 45984  2020-12-21T16:42:32.517
# 37535  2019-08-19T10:48:21.213
# 52361  2020-09-09T14:21:57.233
# 17863  2018-03-01T22:05:38.967
# 34727  2020-08-12T18:38:57.877
# 56184  2021-01-18T23:13:22.910
# 42036  2019-12-20T05:36:21.150
# 51536  2020-08-13T14:36:28.063
#
#                                                    Title  \
# 34094  How is Stochastic Gradient Descent used like M...
# 22952  What is the difference between Gradient Descen...
# 45984                                               None
# 37535                                               None
# 52361  Why do we use stochastic gradient descent in n...
# 17863                                               None
# 34727                                               None
# 56184                                               None
# 42036                                               None
# 51536  Does convergence of loss function is always gu...
#
#                                                     Tags  ...  \
# 34094                   <optimization><gradient-descent>  ...
# 22952  <machine-learning><neural-network><deep-learni...  ...
# 45984                                               None  ...
# 37535                                               None  ...
# 52361  <machine-learning><neural-network><deep-learni...  ...
# 17863                                               None  ...
# 34727                                               None  ...
# 56184                                               None  ...
# 42036                                               None  ...
# 51536                      <loss-function><optimization>  ...
#
#        LastEditorDisplayName  FavoriteCount  \
# 34094                   None            NaN
# 22952                   None            NaN
# 45984                   None            NaN
# 37535                   None            NaN
# 52361                   None            NaN
# 17863                   None            NaN
# 34727                   None            NaN
# 56184                   None            NaN
# 42036                   None            NaN
# 51536                   None            NaN
#
#                                                CleanBody  \
# 34094  As I know, Gradient Descent has three variants...
# 22952  What is the difference between Gradient Descen...
# 45984  Both algorithms are quite similar. The only di...
# 37535  You can see in the following link examples in ...
# 52361  I am a student and I am studying machine learn...
# 17863  It depends a bit on your definition, usually t...
# 34727  Gradient Descent is an optimization method use...
# 56184  Stochastic Gradient Descent (SGD) is an iterat...
# 42036  First, using the appropriate terminology you c...
# 51536  Which of the following is true, given the opti...
#
#                                                   Tokens  \
# 34094  [as, i, know, gradient, descent, has, three, v...
# 22952  [what, is, the, difference, between, gradient,...
# 45984  [both, algorithms, are, quite, similar, the, o...
# 37535  [you, can, see, in, the, following, link, exam...
# 52361  [i, am, a, student, and, i, am, studying, mach...
# 17863  [it, depends, a, bit, on, your, definition, us...
# 34727  [gradient, descent, is, an, optimization, meth...
# 56184  [stochastic, gradient, descent, sgd, is, an, i...
# 42036  [first, using, the, appropriate, terminology, ...
# 51536  [which, of, the, following, is, true, given, t...
#
#                                                    Words  \
# 34094  [a, i, know, gradient, descent, ha, three, var...
# 22952  [what, is, the, difference, between, gradient,...
# 45984  [both, algorithm, are, quite, similar, the, on...
# 37535  [you, can, see, in, the, following, link, exam...
# 52361  [i, am, a, student, and, i, am, studying, mach...
# 17863  [it, depends, a, bit, on, your, definition, us...
# 34727  [gradient, descent, is, an, optimization, meth...
# 56184  [stochastic, gradient, descent, sgd, is, an, i...
# 42036  [first, using, the, appropriate, terminology, ...
# 51536  [which, of, the, following, is, true, given, t...
#
#                                         MeaningfullWords  ScoreBM25  \
# 34094  [know, gradient, descent, ha, three, variant, ...  24.811270
# 22952  [difference, gradient, descent, stochastic, gr...  21.527701
# 45984  [algorithm, quite, similar, difference, come, ...  23.961097
# 37535  [see, following, link, example, numpy, followi...  24.648790
# 52361  [student, studying, machine, learning, focusin...  22.250149
# 17863  [depends, bit, definition, usually, stochastic...  21.581461
# 34727  [gradient, descent, optimization, method, used...  21.166175
# 56184  [stochastic, gradient, descent, sgd, iterative...  20.360440
# 42036  [first, using, appropriate, terminology, say, ...  21.661273
# 51536  [following, true, given, optimal, learning, ra...  22.403807
#
#        CosineSimilarity    XMesure   MMesure
# 34094          0.582938  14.463426  0.874881
# 22952          0.832111  17.913438  0.856994
# 45984          0.587242  14.070957  0.852187
# 37535          0.507326  12.504967  0.847614
# 52361          0.713572  15.877078  0.841815
# 17863          0.698770  15.080484  0.818509
# 34727          0.715019  15.134227  0.811667
# 56184          0.789202  16.068508  0.811190
# 42036          0.598612  12.966702  0.790713
# 51536          0.510951  11.447244  0.785364
#
# [10 rows x 30 columns]

# %% [markdown]
# ## Ranking

# %%
users = pd.read_xml(os.path.join(DATAPATH, 'Users.xml'), parser="etree", encoding="utf8")

# %%
def metadata_ranking(query, top, coef_rep, coef_viewcount):

  results = search(query, 10*top)

  posts_ids = results['Id'].tolist()

  new_scores = []
  reputation_scores = []

  for post_id in posts_ids:

    post_metadata = results.loc[results['Id'] == post_id]
    
    user_Id=post_metadata['OwnerUserId'].tolist()[0]
    user = users.loc[users['Id']==user_Id]
    reputation = user['Reputation'].tolist()
    if len(reputation) != 0:
      reputation_scores.append(reputation[0])
    else:
      reputation_scores.append(1)
    
    post_viewcount = post_metadata['ViewCount'].tolist()[0]
    post_score = post_metadata['MMesure'].tolist()[0]

    if not math.isnan(post_viewcount) :
      new_scores.append((post_score+coef_rep*math.log(reputation_scores[-1]))*math.pow(post_viewcount, coef_viewcount))
    else :
      new_scores.append(post_score+coef_rep*math.log(reputation_scores[-1]))

  results['Reputation'] = reputation_scores
  results['MetadataScore'] = new_scores

  new_ranking = results.nlargest(top, 'MetadataScore')

  return new_ranking

# %%
metadata_ranking(query, top=10, coef_rep=0.5, coef_viewcount=0.2)
# Out:
#           Id  PostTypeId             CreationDate  Score  ViewCount  \
# 22952  36450           1  2018-08-04T06:36:04.657     75   137355.0
# 361      410           1  2014-06-16T18:08:38.623    114   120202.0
# 24067  37941           1  2018-09-07T18:15:11.690     10    20279.0
# 1109    1246           1  2014-10-10T13:34:11.543     10     8760.0
# 8191   14118           1  2016-09-20T21:27:12.427      4     9423.0
# 7770   13525           1  2016-08-18T11:35:25.867      3     3901.0
# 51536  80232           1  2020-08-13T14:00:00.913      4     1259.0
# 34094  53047           1  2019-06-01T14:17:40.917      4      265.0
# 39984  62329           1  2019-10-28T19:48:04.397      0      956.0
# 2033    5349           1  2015-03-18T17:25:32.460      4      801.0
#
#                                                     Body  OwnerUserId  \
# 22952  <p>What is the difference between Gradient Des...      57082.0
# 361    <p>I'm currently working on implementing Stoch...        890.0
# 24067  <p>To my understanding, the SGD classifier, an...      58736.0
# 1109   <p>let's assume that I want to train a stochas...       2576.0
# 8191   <p>I wonder when to use linear regression with...      21254.0
# 7770   <p>I was reading <a href="http://rads.stackove...      13100.0
# 51536  <p>Which of the following is true, given the o...      85353.0
# 34094  <p>As I know, Gradient Descent has three varia...      56922.0
# 39984  <p>Is backpropagation a learning method or an ...      83406.0
# 2033   <p>I'm not sure which word to use to different...       8714.0
#
#               LastActivityDate  \
# 22952  2021-02-07T20:51:58.520
# 361    2020-01-31T16:28:25.547
# 24067  2018-09-07T18:31:58.697
# 1109   2014-11-21T11:50:47.717
# 8191   2016-09-21T00:46:01.750
# 7770   2022-08-15T12:02:09.390
# 51536  2020-08-13T14:36:28.063
# 34094  2020-12-14T16:54:45.387
# 39984  2019-11-27T23:02:00.283
# 2033   2015-12-06T12:17:40.473
#
#                                                    Title  \
# 22952  What is the difference between Gradient Descen...
# 361                             Choosing a learning rate
# 24067  What is the difference between SGD classifier ...
# 1109   Stochastic gradient descent based on vector op...
# 8191   Linear regression - LMS with gradient descent ...
# 7770   Is there any book for modern optimization in P...
# 51536  Does convergence of loss function is always gu...
# 34094  How is Stochastic Gradient Descent used like M...
# 39984   Back-propagation and stochastic gradient descent
# 2033   Terminology: SOMs, batch learning, online lear...
#
#                                                     Tags  ...  \
# 22952  <machine-learning><neural-network><deep-learni...  ...
# 361    <machine-learning><neural-network><deep-learni...  ...
# 24067  <machine-learning><logistic-regression><gradie...  ...
# 1109              <python><gradient-descent><regression>  ...
# 8191               <machine-learning><linear-regression>  ...
# 7770   <beginner><tools><career><reference-request><b...  ...
# 51536                      <loss-function><optimization>  ...
# 34094                   <optimization><gradient-descent>  ...
# 39984  <machine-learning><neural-network><gradient-de...  ...
# 2033                <machine-learning><gradient-descent>  ...
#
#                                                CleanBody  \
# 22952  What is the difference between Gradient Descen...
# 361    I'm currently working on implementing Stochast...
# 24067  To my understanding, the SGD classifier, and L...
# 1109   let's assume that I want to train a stochastic...
# 8191   I wonder when to use linear regression with st...
# 7770   I was reading Modern Optimization with R (Use ...
# 51536  Which of the following is true, given the opti...
# 34094  As I know, Gradient Descent has three variants...
# 39984  Is backpropagation a learning method or an opt...
# 2033   I'm not sure which word to use to differentiat...
#
#                                                   Tokens  \
# 22952  [what, is, the, difference, between, gradient,...
# 361    [i, m, currently, working, on, implementing, s...
# 24067  [to, my, understanding, the, sgd, classifier, ...
# 1109   [let, s, assume, that, i, want, to, train, a, ...
# 8191   [i, wonder, when, to, use, linear, regression,...
# 7770   [i, was, reading, modern, optimization, with, ...
# 51536  [which, of, the, following, is, true, given, t...
# 34094  [as, i, know, gradient, descent, has, three, v...
# 39984  [is, backpropagation, a, learning, method, or,...
# 2033   [i, m, not, sure, which, word, to, use, to, di...
#
#                                                    Words  \
# 22952  [what, is, the, difference, between, gradient,...
# 361    [i, m, currently, working, on, implementing, s...
# 24067  [to, my, understanding, the, sgd, classifier, ...
# 1109   [let, s, assume, that, i, want, to, train, a, ...
# 8191   [i, wonder, when, to, use, linear, regression,...
# 7770   [i, wa, reading, modern, optimization, with, r...
# 51536  [which, of, the, following, is, true, given, t...
# 34094  [a, i, know, gradient, descent, ha, three, var...
# 39984  [is, backpropagation, a, learning, method, or,...
# 2033   [i, m, not, sure, which, word, to, use, to, di...
#
#                                         MeaningfullWords  ScoreBM25  \
# 22952  [difference, gradient, descent, stochastic, gr...  21.527701
# 361    [currently, working, implementing, stochastic,...  15.629559
# 24067  [understanding, sgd, classifier, logistic, reg...  19.106045
# 1109   [let, assume, want, train, stochastic, gradien...  18.367978
# 8191   [wonder, use, linear, regression, stochastic, ...  17.785494
# 7770   [wa, reading, modern, optimization, r, use, r,...  18.758954
# 51536  [following, true, given, optimal, learning, ra...  22.403807
# 34094  [know, gradient, descent, ha, three, variant, ...  24.811270
# 39984  [backpropagation, learning, method, optimisati...  18.047447
# 2033   [sure, word, use, differentiate, self, organiz...  16.159323
#
#        CosineSimilarity    XMesure   MMesure Reputation MetadataScore
# 22952          0.832111  17.913438  0.856994       1039     46.137801
# 361            0.511903   8.000812  0.594527       1824     45.119455
# 24067          0.371866   7.104887  0.650598        674     28.397260
# 1109           0.589199  10.822403  0.694975       1717     27.154312
# 8191           0.459160   8.166393  0.639530       1308     26.359527
# 7770           0.465278   8.728124  0.668829        865     21.169521
# 51536          0.510951  11.447244  0.785364        277     14.996521
# 34094          0.582938  14.463426  0.874881       1117     13.382211
# 39984          0.698776  12.611121  0.718805        168     12.944034
# 2033           0.439779   7.106523  0.587836        141     11.661713
#
# [10 rows x 32 columns]

# %% [markdown]
# ## Visualising Results

# %%
def visualize_output(query, top, coef_rep, coef_viewcount):
    ranking = metadata_ranking(query, top, coef_rep, coef_viewcount)
    return ranking[['Id', 'Title', 'CleanBody', 'OwnerUserId', 'ScoreBM25', 'CosineSimilarity', 'MMesure', 'ViewCount', 'Reputation', 'MetadataScore']]

# %%
visualize_output('how sklearn working', top=10, coef_rep=0.5, coef_viewcount=0.1)
# Out:
#           Id                                              Title  \
# 22556  35869                     How to choose the random seed?
# 832      927  how to impute missing values on numpy array cr...
# 53541  84258      How to choose between Tensorflow and Pytorch?
# 34459  53513      one-hot-encoding categorical data gives error
# 40548  63185  sklearn.feature_selection vs xgboost feature_i...
# 26025  40670              Logistic regression score is negative
# 5358   10476   how to make sklearn pipeline using custom model?
# 21995  34061  sklearn.neighbors.NearestNeighbors - knn for u...
# 23107  36652  How to show progress of sklearn.multioutput.Mu...
# 29632  45933  Why doesn't loss go down during Neural Net tra...
#
#                                                CleanBody  OwnerUserId  \
# 22556  I understand this question can be strange, but...      54395.0
# 832    I'm working on the dataset with lots of NA val...       2854.0
# 53541  Recently I've been working on a pretty vanilla...        303.0
# 34459  I am currently working on the Boston problem h...      73912.0
# 40548  sklearn.feature_selection vs xgboost feature_i...      83275.0
# 26025  I am trying to implement logistic regression a...      51106.0
# 5358   I want to make a sklearn pipeline using the cu...      14310.0
# 21995  From basic theory I know that knn is a supervi...      46748.0
# 23107  Is it possible to show the training progress o...      53890.0
# 29632  I am working on a Kaggle competition and have ...      16111.0
#
#        ScoreBM25  CosineSimilarity   MMesure  ViewCount  Reputation  \
# 22556   6.998337          0.320996  0.588314     5461.0        3398
# 832     7.811963          0.215736  0.613937     2809.0         715
# 53541   7.164608          0.382007  0.618307      600.0        2350
# 34459   7.910799          0.125350  0.593770     3902.0         342
# 40548   6.955838          0.404997  0.610526      241.0        2836
# 26025   6.515500          0.422055  0.584686    10748.0         117
# 5358    7.062588          0.473271  0.638513     4166.0         184
# 21995   6.962655          0.446654  0.623503     6338.0         105
# 23107   8.845673          0.335291  0.722478     4681.0         103
# 29632   7.063059          0.314506  0.590917      959.0         292
#
#        MetadataScore
# 22556      11.003567
# 832         8.628365
# 53541       8.530391
# 34459       8.027517
# 40548       7.935933
# 26025       7.503616
# 5358        7.469954
# 21995       7.080898
# 23107       7.077583
# 29632       6.813756

# %% [markdown]
# ## Querying

# %%
def make_query(natural_query):
    # TODO

    return

# %% [markdown]
# ## Scoring

# %%
# Pas sûr de garder cette partie

# %% [markdown]
# ## Testing

# %%
# TODO
